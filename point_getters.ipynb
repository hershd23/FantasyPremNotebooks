# %%
import os

import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
PATH = '../data/2019-20/players/'
player_list = os.listdir(PATH)

# %%
PLAYER_PATH_1 = PATH + 'Trent_Alexander-Arnold_182/'
gw1_df = pd.read_csv(PLAYER_PATH_1 + 'gw.csv')
gw1_df.columns
# Out:
# Index(['assists', 'bonus', 'bps', 'clean_sheets', 'creativity', 'element',
#        'fixture', 'goals_conceded', 'goals_scored', 'ict_index', 'influence',
#        'kickoff_time', 'minutes', 'opponent_team', 'own_goals',
#        'penalties_missed', 'penalties_saved', 'red_cards', 'round', 'saves',
#        'selected', 'team_a_score', 'team_h_score', 'threat', 'total_points',
#        'transfers_balance', 'transfers_in', 'transfers_out', 'value',
#        'was_home', 'yellow_cards'],
#       dtype='object')

# %%
gw1_screened = gw1_df[['total_points', 'assists', 'clean_sheets', 'element', 'goals_conceded', 'goals_scored', 'opponent_team', 'transfers_balance', 'value']]
gw1_screened
# Out:
#     total_points  assists  clean_sheets  element  goals_conceded  \
# 0              5        1             0      182               1
# 1              1        0             0      182               1
# 2              5        1             0      182               1
# 3             11        1             1      182               0
# 4              2        0             0      182               1
# 5              7        0             0      182               1
# 6              6        0             1      182               0
# 7              3        0             0      182               1
# 8              2        0             0      182               1
# 9              1        0             0      182               1
# 10             7        1             0      182               1
# 11             2        0             0      182               1
# 12             2        0             0      182               1
# ...
