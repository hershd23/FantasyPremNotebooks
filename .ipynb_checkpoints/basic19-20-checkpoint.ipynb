# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %%
PATH = '../data/2019-20/players_raw.csv'

# %%
players_df = pd.read_csv(PATH)

# %%
players_df = players_df[players_df['minutes'] > 1450]

# %%
players_df
# Out:
#      assists  bonus  bps chance_of_playing_next_round  \
# 2          2      1  331                          100
# 4          0      5  305                          100
# 10         5     37  807                          100
# 11         7     16  387                          100
# 13         0     10  591                            0
# ..       ...    ...  ...                          ...
# 644        0      8  680                         None
# 647        2      7  498                          100
# 648        7     12  617                         None
# 650        9     14  522                          100
# 653        0      9  426                          100
#
#     chance_of_playing_this_round  clean_sheets    code  cost_change_event  \
# 2                            100             4  111457                  0
# 4                            100             4   39476                  0
# 10                           100            10   54694                  0
# 11                           100             5   59966                  0
# 13                             0             7   80201                  0
# ..                           ...           ...     ...                ...
# 644                         None            13   38533                  0
# 647                          100            13  171317                  0
# 648                         None            11   19624                  0
# 650                          100             7  159533                  0
# 653                          100            11  151589                  0
#
#      cost_change_event_fall  cost_change_start  ...  threat_rank_type  \
# 2                         0                 -3  ...                98
# 4                         0                 -2  ...                76
# 10                        0                 -1  ...                 7
# 11                        0                 -3  ...                19
# 13                        0                 -2  ...                63
# ..                      ...                ...  ...               ...
# 644                       0                  3  ...                69
# 647                       0                 -3  ...                72
# 648                       0                 -2  ...               133
# 650                       0                  6  ...                32
# 653                       0                 -1  ...                76
#
#      total_points  transfers_in  transfers_in_event  transfers_out  \
# 2              55         65194                   0         134275
# 4              57        182201                   0         231413
# 10            205       3870546                   0        4120318
# 11            118        458912                   0         551879
# 13            114        737120                   0         865543
# ..            ...           ...                 ...            ...
# 644           153       1224396                   0         957926
# 647            97        410866                   0         676439
# 648           113        684882                   0         836481
# 650           130       3191443                   0        2346310
# 653           100       1222056                   0        1550368
#
#      transfers_out_event value_form  value_season    web_name yellow_cards
# 2                      0        0.5          10.6   Kolasinac            4
# 4                      0        0.0          11.9    Sokratis            6
# 10                     0        0.6          18.8  Aubameyang            3
# 11                     0        0.5          12.8   Lacazette            8
# 13                     0        0.0          23.8        Leno            2
# ..                   ...        ...           ...         ...          ...
# 644                    0        0.7          28.9    Patrício            0
# 647                    0        0.6          18.7       Neves            9
# 648                    0        0.4          21.3    Moutinho            7
# 650                    0        0.3          23.2      Traoré            1
# 653                    0        0.8          22.7  Dendoncker            5
#
# [244 rows x 61 columns]

# %%
players_df.sort_values(by=['minutes'], inplace=True, ascending = False)
players_df.columns
# Out:
# Index(['assists', 'bonus', 'bps', 'chance_of_playing_next_round',
#        'chance_of_playing_this_round', 'clean_sheets', 'code',
#        'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
#        'cost_change_start_fall', 'creativity', 'creativity_rank',
#        'creativity_rank_type', 'dreamteam_count', 'element_type', 'ep_next',
#        'ep_this', 'event_points', 'first_name', 'form', 'goals_conceded',
#        'goals_scored', 'ict_index', 'ict_index_rank', 'ict_index_rank_type',
#        'id', 'in_dreamteam', 'influence', 'influence_rank',
#        'influence_rank_type', 'minutes', 'news', 'news_added', 'now_cost',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'photo',
#        'points_per_game', 'red_cards', 'saves', 'second_name',
#        'selected_by_percent', 'special', 'squad_number', 'status', 'team',
#        'team_code', 'threat', 'threat_rank', 'threat_rank_type',
#        'total_points', 'transfers_in', 'transfers_in_event', 'transfers_out',
#        'transfers_out_event', 'value_form', 'value_season', 'web_name',
#        'yellow_cards'],
#       dtype='object')

# %%
screened_players_df = players_df[['first_name', 'second_name', 'web_name', 'element_type', 'assists', 'bonus', 'bps', 'clean_sheets', 'creativity', 'creativity_rank',
       'creativity_rank_type', 'goals_conceded', 'goals_scored', 'ict_index', 'ict_index_rank', 'ict_index_rank_type', 'id', 'influence', 'influence_rank',
       'influence_rank_type', 'minutes', 'own_goals', 'penalties_missed', 'penalties_saved','total_points', 'points_per_game', 'threat', 'threat_rank', 'threat_rank_type','transfers_in', 'transfers_in_event', 'transfers_out',
       'transfers_out_event', 'value_form', 'value_season', 'yellow_cards', 'red_cards', 'now_cost', 'cost_change_event', 'cost_change_event_fall', 'cost_change_start',
       'cost_change_start_fall']]

# %%
screened_players_df.sort_values(by=['minutes'], ascending = False)
screened_players_df[['web_name', 'minutes', 'now_cost', 'total_points', 'points_per_game']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-4925e2a3ae66> in <module>
#       1 screened_players_df.sort_values(by=['minutes'], ascending = False)
# ----> 2 screened_players_df[['web_name', 'minutes', 'now_cost', 'total_points', 'points_per_game']]
#
# D:\Anaconda3\envs\football\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# D:\Anaconda3\envs\football\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# D:\Anaconda3\envs\football\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['points_per_game'] not in index"
